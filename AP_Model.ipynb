# %% [markdown]
# # IMPORTS

# %%
# Clone the Git repository and navigate to the project directory
# !git clone https://github.com/DanteMillerDS/MPA_Predictor.git
# %cd MPA_Predictor

# Install required packages
# !pip install xgboost
# !pip install pytorch-tabnet
# !pip install torch

# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.io
import torch
import uuid
from IPython.display import display
from sklearn.preprocessing import PowerTransformer, QuantileTransformer
import torch
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader
import tensorflow as tf
from pytorch_tabnet.tab_model import TabNetRegressor
import keras
from sklearn.model_selection import KFold


# Set random seeds for reproducibility
np.random.seed(1000)
tf.random.set_seed(1000)

# %% [markdown]
# # PREPROCESSING

# %%
# Read files
file_paths = dict()
file_paths[0] = ["data/s11_dB_freq.txt"]

# Process files
def process_file(file_path):
    datasets = []
    with open(file_path, 'r') as file:
        current_dataset = []
        for line in file:
            if line.startswith("#Parameters"):
                if current_dataset:
                    datasets.append(current_dataset)
                    current_dataset = []
                params_str = line[line.index("{") + 1:line.index("}")]
                params = dict(param.split('=') for param in params_str.split(';'))
                current_dataset.append(params)
            elif line.startswith("#"):
                continue
            else:
                data = line.strip().split('\t')
                current_dataset.append(data)
        if current_dataset:
            datasets.append(current_dataset)
    data = []
    for dataset in datasets:
        permittivity_values = dataset[0]
        df_data = dataset[1:]
        s_parameter_name = file_path.split("_parameter_data_for_")[0]
        df = pd.DataFrame(df_data, columns=["Frequency", f"{s_parameter_name}"])
        df["ID"] = str(uuid.uuid4())[:8]
        for key, value in permittivity_values.items():
            df[key.replace(" ", "")] = value
        data.append(df)
    return data
all_combined_data = []
for index in file_paths:
    for file in file_paths[index]:
        combined_data = process_file(file)
        combined_data = pd.concat(combined_data, ignore_index=True)
        all_combined_data.append(combined_data)
array = []
group_size = 4
for i in range(0, len(all_combined_data), group_size):
    combined_dataframe = pd.concat(all_combined_data[i:i+group_size], axis=1)
    combined_dataframe.reset_index(drop=True, inplace=True)
    array.append(combined_dataframe)
training_dataframe = pd.concat(array, axis=0)
training_dataframe.reset_index(drop=True, inplace=True)
training_dataframe = training_dataframe.loc[:, ~training_dataframe.columns.duplicated()]

# %%
# Print columns
print(training_dataframe.columns)
# Out:
# Index(['Frequency', 'data/s11_dB_freq.txt', 'ID', 'rprobe', 'rin', 'er22',
#        'er2', 'cl', 'r0', 'w', 'L', 't', 'h', 'wy', 'wx', 'er11', 'er1'],
#       dtype='object')

# %%
# Grab specific columns
needed_columns = ["Frequency","data/s11_dB_freq.txt","h","t","er11","er1","w","L"]
training_dataframe = training_dataframe[needed_columns]

# %%
# Define variable names
training_dataframe.columns = ["Frequency","Input_Impedance","Substrate_Thickness","Patch_Thickness","Permittivity_Imaginary","Permittivity_Real","Width","Length"]

# %%
# Print variable names
training_dataframe.columns
# Out:
# Index(['Frequency', 'Input_Impedance', 'Substrate_Thickness',
#        'Patch_Thickness', 'Permittivity_Imaginary', 'Permittivity_Real',
#        'Width', 'Length'],
#       dtype='object')

# %%
# Drop na and applying numeric
training_dataframe.dropna(inplace=True)
columns = training_dataframe.columns[1:]
training_dataframe[columns] = training_dataframe[columns].apply(pd.to_numeric)

# %%
# Describe dataframe
training_dataframe.describe()
# Out:
#        Input_Impedance  Substrate_Thickness  Patch_Thickness  \
# count    100100.000000         1.001000e+05     1.001000e+05
# mean         -3.252633         1.600000e+00     2.000000e-01
# std           4.162713         2.220457e-16     2.775571e-17
# min         -29.213769         1.600000e+00     2.000000e-01
# 25%          -4.395586         1.600000e+00     2.000000e-01
# 50%          -1.654782         1.600000e+00     2.000000e-01
# 75%          -0.417934         1.600000e+00     2.000000e-01
# max           0.140660         1.600000e+00     2.000000e-01
#
#        Permittivity_Imaginary  Permittivity_Real          Width         Length
# count            1.001000e+05       1.001000e+05  100100.000000  100100.000000
# mean             1.000000e-02       2.550000e+00      28.759751      46.015602
# std              1.734732e-18       4.440914e-16      13.298825      21.278120
# min              1.000000e-02       2.550000e+00       5.535593       8.856949
# 25%              1.000000e-02       2.550000e+00      16.560724      26.497158
# 50%              1.000000e-02       2.550000e+00      29.681131      47.489809
# 75%              1.000000e-02       2.550000e+00      40.209226      64.334762
# max              1.000000e-02       2.550000e+00      48.676675      77.882680

# %%
# Print dataframe head
training_dataframe.head(5)
# Out:
#          Frequency  Input_Impedance  Substrate_Thickness  Patch_Thickness  \
# 0  1.0000000000000        -0.163918                  1.6              0.2
# 1  1.0089999437332        -0.131358                  1.6              0.2
# 2  1.0180000066757        -0.068440                  1.6              0.2
# 3  1.0269999504089        -0.013418                  1.6              0.2
# 4  1.0360000133514        -0.000152                  1.6              0.2
#
#    Permittivity_Imaginary  Permittivity_Real      Width     Length
# 0                    0.01               2.55  41.662566  66.660105
# 1                    0.01               2.55  41.662566  66.660105
# 2                    0.01               2.55  41.662566  66.660105
# 3                    0.01               2.55  41.662566  66.660105
# 4                    0.01               2.55  41.662566  66.660105

# %%
# Find lowest impudance value in each set
lowest_impedance_rows = pd.DataFrame(columns=training_dataframe.columns)
for i in range(0,len(training_dataframe),1001):
  subset = training_dataframe[i:i+1001]
  min_impedance_row = subset[subset['Input_Impedance'] == subset['Input_Impedance'].min()]
  lowest_impedance_rows = pd.concat([lowest_impedance_rows, min_impedance_row])

# %%
# Show new dataframe
lowest_impedance_rows
# Out:
#              Frequency  Input_Impedance  Substrate_Thickness  Patch_Thickness  \
# 385    4.4650001525879       -20.224921                  1.6              0.2
# 1344   4.0869998931885       -19.536557                  1.6              0.2
# 2983   9.8290004730225       -24.501126                  1.6              0.2
# 3343   4.0599999427795       -19.490123                  1.6              0.2
# 4503   5.4910001754761       -23.453824                  1.6              0.2
# 5514   5.5809998512268       -11.790161                  1.6              0.2
# 6590   6.2560000419617       -26.042706                  1.6              0.2
# 7578   6.1389999389648       -26.357643                  1.6              0.2
# 8297   3.6010000705719       -20.192231                  1.6              0.2
# 9295   3.5739998817444       -20.878927                  1.6              0.2
# 10879  8.8210000991821       -24.995881                  1.6              0.2
# 11295  3.5559999942780       -21.188886                  1.6              0.2
# 12301  3.6010000705719       -20.315689                  1.6              0.2
# 13648  6.7150001525879       -27.088926                  1.6              0.2
# 14211  2.7730000019073       -20.345695                  1.6              0.2
# 15939  9.3159999847412       -25.888840                  1.6              0.2
# 16729  7.4169998168945       -28.905585                  1.6              0.2
# 17356  4.0510001182556       -19.519568                  1.6              0.2
# 18218  2.7999999523163       -20.436944                  1.6              0.2
# 19307  3.5920000076294       -20.591789                  1.6              0.2
# 20501  5.3289999961853       -23.376495                  1.6              0.2
# 21749  7.5520000457764       -14.619912                  1.6              0.2
# 22204  2.6380000114441       -20.226012                  1.6              0.2
# 23330  3.7630000114441       -19.074872                  1.6              0.2
# 24489  5.1849999427795       -22.981978                  1.6              0.2
# 25441  4.7439999580383       -20.721559                  1.6              0.2
# 26450  4.8159999847412       -20.834497                  1.6              0.2
# 27783  7.8039999008179       -26.954822                  1.6              0.2
# 28509  5.3289999961853       -23.246526                  1.6              0.2
# 29855  8.4340000152588       -26.385402                  1.6              0.2
# 30477  5.0229997634888       -22.056298                  1.6              0.2
# 31779  7.7319998741150       -15.107736                  1.6              0.2
# 32619  6.2829999923706       -26.384604                  1.6              0.2
# 33716  7.1469998359680       -14.066844                  1.6              0.2
# 34544  5.5900001525879       -11.798387                  1.6              0.2
# 35416  4.4289999008179       -20.210836                  1.6              0.2
# 36490  5.0859999656677       -22.363497                  1.6              0.2
# 37562  5.7249999046326       -26.991247                  1.6              0.2
# 38329  3.6189999580383       -19.733862                  1.6              0.2
# 39774  7.6149997711182       -14.763561                  1.6              0.2
# 40730  7.2100000381470       -28.806411                  1.6              0.2
# 41814  7.9569997787476       -26.343668                  1.6              0.2
# 42251  2.8810000419617       -20.667223                  1.6              0.2
# 43242  2.7909998893738       -20.428966                  1.6              0.2
# 44824  8.0200004577637       -28.070645                  1.6              0.2
# 45675  6.6700000762939       -27.007514                  1.6              0.2
# 46728  7.1380000114441       -28.584964                  1.6              0.2
# 47535  5.3920001983643       -23.482632                  1.6              0.2
# 48493  5.0050001144409       -22.019371                  1.6              0.2
# 49467  4.7620000839233       -20.623732                  1.6              0.2
# 50639  6.3010001182556       -26.098870                  1.6              0.2
# 51515  5.1760001182556       -22.795018                  1.6              0.2
# 52534  5.3379998207092       -23.294927                  1.6              0.2
# 53906  8.6770000457764       -25.601362                  1.6              0.2
# 55054  10.000000000000       -13.575597                  1.6              0.2
# 55675  6.5799999237061       -27.185110                  1.6              0.2
# 56344  3.5920000076294       -20.527684                  1.6              0.2
# 57551  5.4460000991821       -27.895354                  1.6              0.2
# 58595  5.8330001831055       -24.564431                  1.6              0.2
# 59748  7.2010002136230       -27.124363                  1.6              0.2
# 60480  4.7800002098083       -20.695648                  1.6              0.2
# 61687  6.6339998245239       -28.384740                  1.6              0.2
# 62674  6.5079998970032       -27.108542                  1.6              0.2
# 63514  5.0590000152588       -22.018096                  1.6              0.2
# 64234  2.5299999713898       -19.838702                  1.6              0.2
# 65353  3.5920000076294       -20.626514                  1.6              0.2
# 66637  6.1389999389648       -26.405004                  1.6              0.2
# 68003  9.4239997863770       -26.103737                  1.6              0.2
# 68965  9.0729999542236       -25.280779                  1.6              0.2
# 69690  6.5890002250671       -27.754008                  1.6              0.2
# 70442  4.3480000495911       -19.985580                  1.6              0.2
# 71698  6.6430001258850       -28.084202                  1.6              0.2
# 72457  4.4650001525879       -20.051749                  1.6              0.2
# 73721  6.8319997787476       -29.213769                  1.6              0.2
# 74234  2.4400000572205       -18.949200                  1.6              0.2
# 75557  5.3379998207092       -26.996459                  1.6              0.2
# 76831  7.7950000762939       -27.008833                  1.6              0.2
# 77710  6.6970000267029       -28.338838                  1.6              0.2
# 78589  5.5989999771118       -23.657060                  1.6              0.2
# 79728  6.8410000801086       -27.732441                  1.6              0.2
# 80560  5.3200001716614       -27.026700                  1.6              0.2
# 81458  4.3930001258850       -20.203024                  1.6              0.2
# 82619  5.8330001831055       -24.567142                  1.6              0.2
# 83652  6.1209998130798       -26.121048                  1.6              0.2
# 84247  2.4670000076294       -19.258402                  1.6              0.2
# 85657  6.1479997634888       -26.077477                  1.6              0.2
# 86502  4.7439999580383       -20.698392                  1.6              0.2
# 87505  4.7620000839233       -20.768508                  1.6              0.2
# 88863  7.9749999046326       -26.194911                  1.6              0.2
# 89641  5.9679999351501       -25.446318                  1.6              0.2
# 90663  6.1570000648499       -12.279316                  1.6              0.2
# 91742  6.8590002059937       -13.644717                  1.6              0.2
# 92678  6.2740001678467       -26.674047                  1.6              0.2
# 93497  4.6360001564026       -20.367337                  1.6              0.2
# 94401  3.7630000114441       -19.073526                  1.6              0.2
# 96065  9.7299995422363       -25.363050                  1.6              0.2
# 96647  5.9590001106262       -25.414828                  1.6              0.2
# 97751  6.8860001564026       -27.873510                  1.6              0.2
# 98961  8.7670001983643       -17.926713                  1.6              0.2
# 99597  5.4819998741150       -27.731912                  1.6              0.2
#
#        Permittivity_Imaginary  Permittivity_Real      Width     Length
# 385                      0.01               2.55  41.662566  66.660105
# 1344                     0.01               2.55  45.760637  73.217019
# 2983                     0.01               2.55  10.714407  17.143051
# 3343                     0.01               2.55  46.101914  73.763062
# 4503                     0.01               2.55  33.456166  53.529866
# 5514                     0.01               2.55   9.389318  15.022909
# 6590                     0.01               2.55  17.532420  28.051872
# 7578                     0.01               2.55  29.609668  47.375469
# 8297                     0.01               2.55  48.087808  76.940492
# 9295                     0.01               2.55  48.419984  77.471975
# 10879                    0.01               2.55  12.092589  19.348142
# 11295                    0.01               2.55  48.676675  77.882680
# 12301                    0.01               2.55  48.072513  76.916020
# 13648                    0.01               2.55  26.841904  42.947047
# 14211                    0.01               2.55  41.012621  65.620194
# 15939                    0.01               2.55  11.384885  18.215816
# 16729                    0.01               2.55  23.979258  38.366812
# 17356                    0.01               2.55  46.208099  73.932958
# 18218                    0.01               2.55  40.649330  65.038928
# 19307                    0.01               2.55  48.177159  77.083455
# 20501                    0.01               2.55  34.508331  55.213330
# 21749                    0.01               2.55   6.607026  10.571241
# 22204                    0.01               2.55  43.210819  69.137310
# 23330                    0.01               2.55  47.029696  75.247514
# 24489                    0.01               2.55  35.543082  56.868931
# 25441                    0.01               2.55  39.098306  62.557289
# 26450                    0.01               2.55  38.440961  61.505538
# 27783                    0.01               2.55  22.650216  36.240345
# 28509                    0.01               2.55  34.496505  55.194408
# 29855                    0.01               2.55  12.703401  20.325442
# 30477                    0.01               2.55  36.772074  58.835318
# 31779                    0.01               2.55   6.432478  10.291965
# 32619                    0.01               2.55  17.461534  27.938455
# 33716                    0.01               2.55   7.077713  11.324340
# 34544                    0.01               2.55   9.370930  14.993488
# 35416                    0.01               2.55  42.055602  67.288964
# 36490                    0.01               2.55  36.267288  58.027661
# 37562                    0.01               2.55  19.269477  30.831163
# 38329                    0.01               2.55  47.759992  76.415988
# 39774                    0.01               2.55   6.550074  10.480118
# 40730                    0.01               2.55  24.743496  39.589594
# 41814                    0.01               2.55  22.170131  35.472209
# 42251                    0.01               2.55  39.448255  63.117209
# 43242                    0.01               2.55  40.783996  65.254393
# 44824                    0.01               2.55  13.409267  21.454828
# 45675                    0.01               2.55  27.039398  43.263036
# 46728                    0.01               2.55  25.051379  40.082206
# 47535                    0.01               2.55  34.084085  54.534537
# 48493                    0.01               2.55  36.921417  59.074268
# 49467                    0.01               2.55  38.960901  62.337441
# 50639                    0.01               2.55  17.421128  27.873806
# 51515                    0.01               2.55  35.586620  56.938593
# 52534                    0.01               2.55  34.479410  55.167056
# 53906                    0.01               2.55  12.317528  19.708045
# 55054                    0.01               2.55  10.354896  16.567833
# 55675                    0.01               2.55  27.426382  43.882212
# 56344                    0.01               2.55  48.188478  77.101565
# 57551                    0.01               2.55  20.317358  32.507772
# 58595                    0.01               2.55  31.337049  50.139278
# 59748                    0.01               2.55  15.071537  24.114460
# 60480                    0.01               2.55  38.807018  62.091228
# 61687                    0.01               2.55  16.479280  26.366848
# 62674                    0.01               2.55  27.768067  44.428908
# 63514                    0.01               2.55  36.458453  58.333524
# 64234                    0.01               2.55  45.090646  72.145034
# 65353                    0.01               2.55  48.168114  77.068983
# 66637                    0.01               2.55  29.624699  47.399518
# 68003                    0.01               2.55  11.238100  17.980960
# 68965                    0.01               2.55  11.718230  18.749168
# 69690                    0.01               2.55  16.587871  26.540594
# 70442                    0.01               2.55  42.832277  68.531642
# 71698                    0.01               2.55  16.442698  26.308317
# 72457                    0.01               2.55  41.642817  66.628507
# 73721                    0.01               2.55  15.958624  25.533798
# 74234                    0.01               2.55  46.816863  74.906981
# 75557                    0.01               2.55  20.749269  33.198831
# 76831                    0.01               2.55  13.846786  22.154858
# 77710                    0.01               2.55  16.298774  26.078038
# 78589                    0.01               2.55  32.722010  52.355217
# 79728                    0.01               2.55  26.297998  42.076797
# 80560                    0.01               2.55  20.824678  33.319485
# 81458                    0.01               2.55  42.387288  67.819661
# 82619                    0.01               2.55  31.336884  50.139015
# 83652                    0.01               2.55  29.737562  47.580100
# 84247                    0.01               2.55  46.273715  74.037944
# 85657                    0.01               2.55  17.862756  28.580409
# 86502                    0.01               2.55  39.074010  62.518416
# 87505                    0.01               2.55  38.917809  62.268495
# 88863                    0.01               2.55  22.120063  35.392101
# 89641                    0.01               2.55  30.551974  48.883158
# 90663                    0.01               2.55   8.413443  13.461509
# 91742                    0.01               2.55   7.427755  11.884409
# 92678                    0.01               2.55  28.885890  46.217424
# 93497                    0.01               2.55  40.062525  64.100041
# 94401                    0.01               2.55  47.030481  75.248769
# 96065                    0.01               2.55  10.845779  17.353247
# 96647                    0.01               2.55  30.597065  48.955304
# 97751                    0.01               2.55  26.122579  41.796126
# 98961                    0.01               2.55   5.535593   8.856949
# 99597                    0.01               2.55  20.170519  32.272830

# %%
# Set training dataframe equaled to lowest imepedance dataframe
training_dataframe = lowest_impedance_rows

# %% [markdown]
# # DATA VISUALIZATION

# %%
# Plot columns
plt.figure(figsize=(24, 8))
for i, column in enumerate(training_dataframe.columns):
    plt.subplot(2,4 , i+1)
    plt.hist(training_dataframe[column], bins=20, edgecolor='black')
    plt.title(column)
    plt.xlabel('Value')
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# Grabbing column means
columns = ["Input_Impedance","Width","Length"]
training_mean_predicted_values = training_dataframe.groupby('Frequency')[columns].mean()

# %%
# Showing mean for the input impedance
q25 = np.percentile(training_dataframe["Input_Impedance"], 25)
q50 = np.percentile(training_dataframe["Input_Impedance"], 50)
q75 = np.percentile(training_dataframe["Input_Impedance"], 75)
plt.hist(training_dataframe["Input_Impedance"])
plt.xlabel("Input_Impedance")
plt.ylabel("Frequency")
plt.title("Training: Histogram of Input Impedance Values")
plt.axvline(q25, color='red', linestyle='dashed', linewidth=2, label='25th Percentile (Q1)')
plt.axvline(q50, color='green', linestyle='dashed', linewidth=2, label='50th Percentile (Median)')
plt.axvline(q75, color='blue', linestyle='dashed', linewidth=2, label='75th Percentile (Q3)')
plt.legend()
plt.show()

# %%
# Showing mean for the width
q25 = np.percentile(training_dataframe["Width"], 25)
q50 = np.percentile(training_dataframe["Width"], 50)
q75 = np.percentile(training_dataframe["Width"], 75)
plt.hist(training_dataframe["Width"])
plt.xlabel("Width")
plt.ylabel("Frequency")
plt.title("Training: Histogram of Width Values")
plt.axvline(q25, color='red', linestyle='dashed', linewidth=2, label='25th Percentile (Q1)')
plt.axvline(q50, color='green', linestyle='dashed', linewidth=2, label='50th Percentile (Median)')
plt.axvline(q75, color='blue', linestyle='dashed', linewidth=2, label='75th Percentile (Q3)')
plt.legend()
plt.show()

# %%
# Showing mean for the length
q25 = np.percentile(training_dataframe["Length"], 25)
q50 = np.percentile(training_dataframe["Length"], 50)
q75 = np.percentile(training_dataframe["Length"], 75)
plt.hist(training_dataframe["Length"])
plt.xlabel("Length")
plt.ylabel("Frequency")
plt.title("Training: Histogram of Length Values")
plt.axvline(q25, color='red', linestyle='dashed', linewidth=2, label='25th Percentile (Q1)')
plt.axvline(q50, color='green', linestyle='dashed', linewidth=2, label='50th Percentile (Median)')
plt.axvline(q75, color='blue', linestyle='dashed', linewidth=2, label='75th Percentile (Q3)')
plt.legend()
plt.show()

# %%
# Plot mean over frequencies
plt.figure(figsize=(12, 6))
for col in training_mean_predicted_values.columns:
    plt.plot(training_mean_predicted_values.index, training_mean_predicted_values[col], label=col)
plt.xlabel('Frequency')
plt.ylabel('Mean Value')
plt.title('Training: Mean Values of Variables over Different Frequencies')
plt.legend()
plt.show()

# %% [markdown]
# # DATA MANIPULATION

# %%
# Divide by 100
training_dataframe["Substrate_Thickness"] /= 100
training_dataframe["Permittivity_Real"] /= 100

# %%
# Power transform
bc = PowerTransformer()
bc.fit(training_dataframe[["Frequency"]])
training_dataframe[training_dataframe[["Frequency"]].columns] = bc.transform(training_dataframe[["Frequency"]])
bc = PowerTransformer()
bc.fit(training_dataframe[["Input_Impedance","Width","Length"]])
training_dataframe[training_dataframe[["Input_Impedance","Width","Length"]].columns] = bc.transform(training_dataframe[["Input_Impedance","Width","Length"]])

# %%
# Plot
plt.figure(figsize=(24, 8))
for i, column in enumerate(training_dataframe.columns):
    plt.subplot(2,4 , i+1)
    plt.hist(training_dataframe[column], bins=20, edgecolor='black')
    plt.title(column)
    plt.xlabel('Value')
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# # MODELS

# %%
# Hyperparameters
LR = 0.001
L2 = 0.0001
WD = 0.00001

# %%
# Column names
columns = []
for column in training_dataframe.columns:
    if column not in ["Width","Length","Input_Impedance"]:
        columns.append(column)
columns
# Out:
# ['Frequency',
#  'Substrate_Thickness',
#  'Patch_Thickness',
#  'Permittivity_Imaginary',
#  'Permittivity_Real']

# %%
# K fold
X_train = training_dataframe[columns].values
y_train = training_dataframe[["Width","Length","Input_Impedance"]].values
selected_indices = np.random.permutation(len(training_dataframe))
X_selected = X_train[selected_indices]
y_selected = y_train[selected_indices]
train_indices, test_indices = train_test_split(selected_indices, test_size=0.1, random_state=100)
kf = KFold(n_splits=5, shuffle=True, random_state=100)
X_train_indices = dict()
X_val_indices = dict()
X_test_indices = dict()
for index, (train_indices, val_indices) in enumerate(kf.split(train_indices)):
    X_train_indices[index] = train_indices
    X_val_indices[index] = val_indices
    X_test_indices[index] = test_indices

# %%
# Showing number of observations
num_obs_train = len(X_selected[train_indices])
num_obs_val = len(X_selected[val_indices])
num_obs_test = len(X_selected[test_indices])
total_obs = num_obs_train + num_obs_val + num_obs_test
data = {'Dataset': ['Training', 'Validation', 'Test', 'Total'],
            'Number of Observations': [num_obs_train, num_obs_val, num_obs_test, total_obs]}
observations_table = pd.DataFrame(data)
print(observations_table)
# Out:
#       Dataset  Number of Observations
# 0    Training                      72
# 1  Validation                      18
# 2        Test                      10
# 3       Total                     100

# %%
# Train models
def train_models(X_train,y_train,X_val,y_val):

    def rmse_loss(y_true, y_pred):
      squared_error = tf.square(y_true - y_pred)
      mean_squared_error = tf.reduce_mean(squared_error)
      root_mean_squared_error = tf.sqrt(mean_squared_error)
      return root_mean_squared_error

    nn_model = keras.Sequential([
        keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],),kernel_initializer='he_uniform', kernel_regularizer=tf.keras.regularizers.l2(L2)),
        keras.layers.Dense(64, activation='relu', kernel_initializer='he_uniform',kernel_regularizer=tf.keras.regularizers.l2(L2)),
        keras.layers.Dense(32, activation='relu', kernel_initializer='he_uniform',kernel_regularizer=tf.keras.regularizers.l2(L2)),
        keras.layers.Dense(16, activation='relu', kernel_initializer='he_uniform',kernel_regularizer=tf.keras.regularizers.l2(L2)),
        keras.layers.Dense(y_train.shape[1], activation='linear')
    ])


    nn_model.compile(optimizer=tf.optimizers.Adam(learning_rate=L2,weight_decay=WD),
                  loss=[rmse_loss],
                  metrics=[tf.metrics.MeanAbsoluteError(), tf.metrics.MeanSquaredError()])
    nn_model.summary()
    history = nn_model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100,shuffle=True)
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['mean_absolute_error'])
    plt.plot(history.history['val_mean_absolute_error'])
    plt.title('FNN: Mean Absolute Error')
    plt.xlabel('Epoch')
    plt.ylabel('Mean Absolute Error')
    plt.legend(['Train', 'Validation'])
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('FNN: Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['Train', 'Validation'])
    plt.tight_layout()
    plt.show()

    xgb_model = xgb.XGBRegressor(n_jobs=-1,device="gpu",n_estimators=250,eval_metric=mean_absolute_error,verbosity=3,max_depth=6)
    xgb_model.fit(X_train, y_train)

    X_train_tensor = torch.tensor(X_train , dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
    X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
    y_val_tensor = torch.tensor(y_val, dtype=torch.float32)
    tabnet_model = TabNetRegressor(device_name = "cuda")
    tabnet_model.fit(
        X_train, y_train,
        eval_set=[(X_val, y_val)],
        eval_metric=['mae'],
        max_epochs=75,
        batch_size = 5
    )
    return nn_model, xgb_model, tabnet_model

# %%
# Call train models function on each k fold
model_dictionary = dict()
for i in range(index+1):
  X_train_index = X_train_indices[i]
  X_val_index = X_val_indices[i]
  X_test_index = X_test_indices[i]
  X_train = X_selected[X_train_index]
  y_train = y_selected[X_train_index]
  X_val = X_selected[X_val_index]
  y_val = y_selected[X_val_index]
  X_test = X_selected[X_test_index]
  y_test = y_selected[X_test_index]
  X_train = X_train.astype(float)
  y_train = y_train.astype(float)
  X_val = X_val.astype(float)
  y_val = y_val.astype(float)
  X_test = X_test.astype(float)
  y_test = y_test.astype(float)

  nn_model, xgb_model, tabnet_model = train_models(X_train,y_train,X_val,y_val)
  model_dictionary[i] = [nn_model,xgb_model,tabnet_model]
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               768
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 16)                528
#
#  dense_4 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 11683 (45.64 KB)
# Trainable params: 11683 (45.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 3/3 [==============================] - 8s 413ms/step - loss: 1.0635 - mean_absolute_error: 0.8274 - mean_squared_error: 1.0400 - val_loss: 1.0503 - val_mean_absolute_error: 0.8371 - val_mean_squared_error: 1.0038
# Epoch 2/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0376 - mean_absolute_error: 0.8066 - mean_squared_error: 0.9819 - val_loss: 1.0262 - val_mean_absolute_error: 0.8176 - val_mean_squared_error: 0.9561
# Epoch 3/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0124 - mean_absolute_error: 0.7874 - mean_squared_error: 0.9313 - val_loss: 1.0020 - val_mean_absolute_error: 0.7969 - val_mean_squared_error: 0.9094
# Epoch 4/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9863 - mean_absolute_error: 0.7663 - mean_squared_error: 0.8811 - val_loss: 0.9779 - val_mean_absolute_error: 0.7755 - val_mean_squared_error: 0.8642
# Epoch 5/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9622 - mean_absolute_error: 0.7481 - mean_squared_error: 0.8385 - val_loss: 0.9602 - val_mean_absolute_error: 0.7597 - val_mean_squared_error: 0.8316
# Epoch 6/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9421 - mean_absolute_error: 0.7329 - mean_squared_error: 0.8041 - val_loss: 0.9467 - val_mean_absolute_error: 0.7472 - val_mean_squared_error: 0.8072
# Epoch 7/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9285 - mean_absolute_error: 0.7198 - mean_squared_error: 0.7774 - val_loss: 0.9349 - val_mean_absolute_error: 0.7363 - val_mean_squared_error: 0.7862
# Epoch 8/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9132 - mean_absolute_error: 0.7077 - mean_squared_error: 0.7553 - val_loss: 0.9239 - val_mean_absolute_error: 0.7255 - val_mean_squared_error: 0.7668
# Epoch 9/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9057 - mean_absolute_error: 0.6969 - mean_squared_error: 0.7360 - val_loss: 0.9141 - val_mean_absolute_error: 0.7151 - val_mean_squared_error: 0.7498
# Epoch 10/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8943 - mean_absolute_error: 0.6866 - mean_squared_error: 0.7185 - val_loss: 0.9049 - val_mean_absolute_error: 0.7049 - val_mean_squared_error: 0.7340
# Epoch 11/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8834 - mean_absolute_error: 0.6759 - mean_squared_error: 0.7012 - val_loss: 0.8963 - val_mean_absolute_error: 0.6963 - val_mean_squared_error: 0.7195
# Epoch 12/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8693 - mean_absolute_error: 0.6668 - mean_squared_error: 0.6847 - val_loss: 0.8882 - val_mean_absolute_error: 0.6889 - val_mean_squared_error: 0.7058
# Epoch 13/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8646 - mean_absolute_error: 0.6608 - mean_squared_error: 0.6717 - val_loss: 0.8803 - val_mean_absolute_error: 0.6814 - val_mean_squared_error: 0.6927
# Epoch 14/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8491 - mean_absolute_error: 0.6545 - mean_squared_error: 0.6589 - val_loss: 0.8728 - val_mean_absolute_error: 0.6737 - val_mean_squared_error: 0.6803
# Epoch 15/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8488 - mean_absolute_error: 0.6474 - mean_squared_error: 0.6460 - val_loss: 0.8660 - val_mean_absolute_error: 0.6662 - val_mean_squared_error: 0.6691
# Epoch 16/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8431 - mean_absolute_error: 0.6405 - mean_squared_error: 0.6343 - val_loss: 0.8597 - val_mean_absolute_error: 0.6586 - val_mean_squared_error: 0.6590
# Epoch 17/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8214 - mean_absolute_error: 0.6335 - mean_squared_error: 0.6236 - val_loss: 0.8541 - val_mean_absolute_error: 0.6513 - val_mean_squared_error: 0.6499
# Epoch 18/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8223 - mean_absolute_error: 0.6272 - mean_squared_error: 0.6140 - val_loss: 0.8489 - val_mean_absolute_error: 0.6446 - val_mean_squared_error: 0.6417
# Epoch 19/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8228 - mean_absolute_error: 0.6206 - mean_squared_error: 0.6049 - val_loss: 0.8442 - val_mean_absolute_error: 0.6381 - val_mean_squared_error: 0.6341
# Epoch 20/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8200 - mean_absolute_error: 0.6140 - mean_squared_error: 0.5965 - val_loss: 0.8396 - val_mean_absolute_error: 0.6320 - val_mean_squared_error: 0.6269
# Epoch 21/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8112 - mean_absolute_error: 0.6080 - mean_squared_error: 0.5881 - val_loss: 0.8354 - val_mean_absolute_error: 0.6263 - val_mean_squared_error: 0.6203
# Epoch 22/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8045 - mean_absolute_error: 0.6022 - mean_squared_error: 0.5804 - val_loss: 0.8313 - val_mean_absolute_error: 0.6207 - val_mean_squared_error: 0.6139
# Epoch 23/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8044 - mean_absolute_error: 0.5966 - mean_squared_error: 0.5729 - val_loss: 0.8273 - val_mean_absolute_error: 0.6150 - val_mean_squared_error: 0.6077
# Epoch 24/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7978 - mean_absolute_error: 0.5912 - mean_squared_error: 0.5653 - val_loss: 0.8235 - val_mean_absolute_error: 0.6095 - val_mean_squared_error: 0.6019
# Epoch 25/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7891 - mean_absolute_error: 0.5859 - mean_squared_error: 0.5586 - val_loss: 0.8199 - val_mean_absolute_error: 0.6047 - val_mean_squared_error: 0.5963
# Epoch 26/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7878 - mean_absolute_error: 0.5812 - mean_squared_error: 0.5519 - val_loss: 0.8166 - val_mean_absolute_error: 0.6029 - val_mean_squared_error: 0.5912
# Epoch 27/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7822 - mean_absolute_error: 0.5768 - mean_squared_error: 0.5451 - val_loss: 0.8133 - val_mean_absolute_error: 0.6009 - val_mean_squared_error: 0.5863
# Epoch 28/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7802 - mean_absolute_error: 0.5730 - mean_squared_error: 0.5392 - val_loss: 0.8101 - val_mean_absolute_error: 0.5987 - val_mean_squared_error: 0.5813
# Epoch 29/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7576 - mean_absolute_error: 0.5697 - mean_squared_error: 0.5332 - val_loss: 0.8071 - val_mean_absolute_error: 0.5971 - val_mean_squared_error: 0.5768
# Epoch 30/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.7721 - mean_absolute_error: 0.5672 - mean_squared_error: 0.5287 - val_loss: 0.8043 - val_mean_absolute_error: 0.5960 - val_mean_squared_error: 0.5727
# Epoch 31/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7698 - mean_absolute_error: 0.5637 - mean_squared_error: 0.5233 - val_loss: 0.8018 - val_mean_absolute_error: 0.5944 - val_mean_squared_error: 0.5689
# Epoch 32/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7666 - mean_absolute_error: 0.5600 - mean_squared_error: 0.5185 - val_loss: 0.7993 - val_mean_absolute_error: 0.5926 - val_mean_squared_error: 0.5653
# Epoch 33/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7613 - mean_absolute_error: 0.5570 - mean_squared_error: 0.5146 - val_loss: 0.7969 - val_mean_absolute_error: 0.5907 - val_mean_squared_error: 0.5617
# Epoch 34/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7435 - mean_absolute_error: 0.5535 - mean_squared_error: 0.5105 - val_loss: 0.7948 - val_mean_absolute_error: 0.5891 - val_mean_squared_error: 0.5585
# Epoch 35/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7470 - mean_absolute_error: 0.5498 - mean_squared_error: 0.5065 - val_loss: 0.7929 - val_mean_absolute_error: 0.5879 - val_mean_squared_error: 0.5557
# Epoch 36/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7507 - mean_absolute_error: 0.5463 - mean_squared_error: 0.5024 - val_loss: 0.7908 - val_mean_absolute_error: 0.5864 - val_mean_squared_error: 0.5527
# Epoch 37/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7488 - mean_absolute_error: 0.5436 - mean_squared_error: 0.4986 - val_loss: 0.7889 - val_mean_absolute_error: 0.5855 - val_mean_squared_error: 0.5499
# Epoch 38/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7453 - mean_absolute_error: 0.5410 - mean_squared_error: 0.4949 - val_loss: 0.7872 - val_mean_absolute_error: 0.5848 - val_mean_squared_error: 0.5475
# Epoch 39/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7482 - mean_absolute_error: 0.5386 - mean_squared_error: 0.4914 - val_loss: 0.7856 - val_mean_absolute_error: 0.5837 - val_mean_squared_error: 0.5451
# Epoch 40/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7379 - mean_absolute_error: 0.5359 - mean_squared_error: 0.4880 - val_loss: 0.7839 - val_mean_absolute_error: 0.5823 - val_mean_squared_error: 0.5425
# Epoch 41/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7386 - mean_absolute_error: 0.5331 - mean_squared_error: 0.4844 - val_loss: 0.7823 - val_mean_absolute_error: 0.5810 - val_mean_squared_error: 0.5403
# Epoch 42/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7269 - mean_absolute_error: 0.5308 - mean_squared_error: 0.4815 - val_loss: 0.7809 - val_mean_absolute_error: 0.5796 - val_mean_squared_error: 0.5382
# Epoch 43/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7335 - mean_absolute_error: 0.5279 - mean_squared_error: 0.4779 - val_loss: 0.7795 - val_mean_absolute_error: 0.5782 - val_mean_squared_error: 0.5363
# Epoch 44/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7341 - mean_absolute_error: 0.5258 - mean_squared_error: 0.4749 - val_loss: 0.7784 - val_mean_absolute_error: 0.5772 - val_mean_squared_error: 0.5347
# Epoch 45/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7300 - mean_absolute_error: 0.5238 - mean_squared_error: 0.4720 - val_loss: 0.7774 - val_mean_absolute_error: 0.5764 - val_mean_squared_error: 0.5333
# Epoch 46/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7298 - mean_absolute_error: 0.5217 - mean_squared_error: 0.4694 - val_loss: 0.7765 - val_mean_absolute_error: 0.5757 - val_mean_squared_error: 0.5320
# Epoch 47/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7241 - mean_absolute_error: 0.5197 - mean_squared_error: 0.4667 - val_loss: 0.7754 - val_mean_absolute_error: 0.5744 - val_mean_squared_error: 0.5305
# Epoch 48/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7217 - mean_absolute_error: 0.5170 - mean_squared_error: 0.4639 - val_loss: 0.7741 - val_mean_absolute_error: 0.5722 - val_mean_squared_error: 0.5285
# Epoch 49/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7188 - mean_absolute_error: 0.5147 - mean_squared_error: 0.4616 - val_loss: 0.7728 - val_mean_absolute_error: 0.5704 - val_mean_squared_error: 0.5267
# Epoch 50/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7244 - mean_absolute_error: 0.5120 - mean_squared_error: 0.4590 - val_loss: 0.7714 - val_mean_absolute_error: 0.5683 - val_mean_squared_error: 0.5247
# Epoch 51/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7170 - mean_absolute_error: 0.5098 - mean_squared_error: 0.4567 - val_loss: 0.7703 - val_mean_absolute_error: 0.5665 - val_mean_squared_error: 0.5231
# Epoch 52/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7207 - mean_absolute_error: 0.5076 - mean_squared_error: 0.4544 - val_loss: 0.7692 - val_mean_absolute_error: 0.5647 - val_mean_squared_error: 0.5217
# Epoch 53/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7188 - mean_absolute_error: 0.5058 - mean_squared_error: 0.4523 - val_loss: 0.7681 - val_mean_absolute_error: 0.5628 - val_mean_squared_error: 0.5200
# Epoch 54/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7115 - mean_absolute_error: 0.5039 - mean_squared_error: 0.4501 - val_loss: 0.7671 - val_mean_absolute_error: 0.5611 - val_mean_squared_error: 0.5187
# Epoch 55/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7095 - mean_absolute_error: 0.5019 - mean_squared_error: 0.4480 - val_loss: 0.7663 - val_mean_absolute_error: 0.5596 - val_mean_squared_error: 0.5175
# Epoch 56/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7105 - mean_absolute_error: 0.5002 - mean_squared_error: 0.4461 - val_loss: 0.7656 - val_mean_absolute_error: 0.5583 - val_mean_squared_error: 0.5166
# Epoch 57/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7057 - mean_absolute_error: 0.4983 - mean_squared_error: 0.4443 - val_loss: 0.7650 - val_mean_absolute_error: 0.5567 - val_mean_squared_error: 0.5158
# Epoch 58/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7115 - mean_absolute_error: 0.4961 - mean_squared_error: 0.4426 - val_loss: 0.7648 - val_mean_absolute_error: 0.5549 - val_mean_squared_error: 0.5155
# Epoch 59/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7083 - mean_absolute_error: 0.4933 - mean_squared_error: 0.4412 - val_loss: 0.7646 - val_mean_absolute_error: 0.5532 - val_mean_squared_error: 0.5153
# Epoch 60/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6892 - mean_absolute_error: 0.4911 - mean_squared_error: 0.4397 - val_loss: 0.7643 - val_mean_absolute_error: 0.5513 - val_mean_squared_error: 0.5148
# Epoch 61/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7028 - mean_absolute_error: 0.4886 - mean_squared_error: 0.4384 - val_loss: 0.7637 - val_mean_absolute_error: 0.5487 - val_mean_squared_error: 0.5140
# Epoch 62/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7037 - mean_absolute_error: 0.4866 - mean_squared_error: 0.4373 - val_loss: 0.7630 - val_mean_absolute_error: 0.5465 - val_mean_squared_error: 0.5131
# Epoch 63/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7049 - mean_absolute_error: 0.4854 - mean_squared_error: 0.4362 - val_loss: 0.7624 - val_mean_absolute_error: 0.5446 - val_mean_squared_error: 0.5123
# Epoch 64/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7055 - mean_absolute_error: 0.4841 - mean_squared_error: 0.4353 - val_loss: 0.7617 - val_mean_absolute_error: 0.5428 - val_mean_squared_error: 0.5114
# Epoch 65/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6951 - mean_absolute_error: 0.4832 - mean_squared_error: 0.4343 - val_loss: 0.7610 - val_mean_absolute_error: 0.5419 - val_mean_squared_error: 0.5103
# Epoch 66/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6916 - mean_absolute_error: 0.4823 - mean_squared_error: 0.4334 - val_loss: 0.7603 - val_mean_absolute_error: 0.5417 - val_mean_squared_error: 0.5094
# Epoch 67/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7003 - mean_absolute_error: 0.4816 - mean_squared_error: 0.4325 - val_loss: 0.7598 - val_mean_absolute_error: 0.5419 - val_mean_squared_error: 0.5088
# Epoch 68/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6956 - mean_absolute_error: 0.4809 - mean_squared_error: 0.4314 - val_loss: 0.7596 - val_mean_absolute_error: 0.5421 - val_mean_squared_error: 0.5085
# Epoch 69/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6988 - mean_absolute_error: 0.4799 - mean_squared_error: 0.4303 - val_loss: 0.7596 - val_mean_absolute_error: 0.5425 - val_mean_squared_error: 0.5084
# Epoch 70/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6898 - mean_absolute_error: 0.4784 - mean_squared_error: 0.4293 - val_loss: 0.7604 - val_mean_absolute_error: 0.5432 - val_mean_squared_error: 0.5097
# Epoch 71/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6810 - mean_absolute_error: 0.4764 - mean_squared_error: 0.4288 - val_loss: 0.7616 - val_mean_absolute_error: 0.5444 - val_mean_squared_error: 0.5114
# Epoch 72/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6920 - mean_absolute_error: 0.4742 - mean_squared_error: 0.4276 - val_loss: 0.7623 - val_mean_absolute_error: 0.5454 - val_mean_squared_error: 0.5125
# Epoch 73/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6920 - mean_absolute_error: 0.4731 - mean_squared_error: 0.4272 - val_loss: 0.7631 - val_mean_absolute_error: 0.5465 - val_mean_squared_error: 0.5137
# Epoch 74/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6943 - mean_absolute_error: 0.4717 - mean_squared_error: 0.4259 - val_loss: 0.7629 - val_mean_absolute_error: 0.5469 - val_mean_squared_error: 0.5134
# Epoch 75/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6851 - mean_absolute_error: 0.4716 - mean_squared_error: 0.4251 - val_loss: 0.7632 - val_mean_absolute_error: 0.5475 - val_mean_squared_error: 0.5139
# Epoch 76/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6973 - mean_absolute_error: 0.4712 - mean_squared_error: 0.4244 - val_loss: 0.7632 - val_mean_absolute_error: 0.5477 - val_mean_squared_error: 0.5139
# Epoch 77/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6969 - mean_absolute_error: 0.4708 - mean_squared_error: 0.4237 - val_loss: 0.7628 - val_mean_absolute_error: 0.5477 - val_mean_squared_error: 0.5133
# Epoch 78/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6902 - mean_absolute_error: 0.4704 - mean_squared_error: 0.4230 - val_loss: 0.7628 - val_mean_absolute_error: 0.5480 - val_mean_squared_error: 0.5134
# Epoch 79/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6937 - mean_absolute_error: 0.4698 - mean_squared_error: 0.4224 - val_loss: 0.7630 - val_mean_absolute_error: 0.5484 - val_mean_squared_error: 0.5137
# Epoch 80/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6955 - mean_absolute_error: 0.4695 - mean_squared_error: 0.4218 - val_loss: 0.7631 - val_mean_absolute_error: 0.5488 - val_mean_squared_error: 0.5139
# Epoch 81/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6911 - mean_absolute_error: 0.4692 - mean_squared_error: 0.4214 - val_loss: 0.7634 - val_mean_absolute_error: 0.5488 - val_mean_squared_error: 0.5144
# Epoch 82/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6906 - mean_absolute_error: 0.4684 - mean_squared_error: 0.4206 - val_loss: 0.7637 - val_mean_absolute_error: 0.5488 - val_mean_squared_error: 0.5149
# Epoch 83/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6902 - mean_absolute_error: 0.4678 - mean_squared_error: 0.4202 - val_loss: 0.7642 - val_mean_absolute_error: 0.5487 - val_mean_squared_error: 0.5157
# Epoch 84/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6812 - mean_absolute_error: 0.4664 - mean_squared_error: 0.4196 - val_loss: 0.7647 - val_mean_absolute_error: 0.5483 - val_mean_squared_error: 0.5164
# Epoch 85/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6801 - mean_absolute_error: 0.4642 - mean_squared_error: 0.4200 - val_loss: 0.7647 - val_mean_absolute_error: 0.5474 - val_mean_squared_error: 0.5164
# Epoch 86/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6824 - mean_absolute_error: 0.4628 - mean_squared_error: 0.4195 - val_loss: 0.7638 - val_mean_absolute_error: 0.5464 - val_mean_squared_error: 0.5152
# Epoch 87/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6808 - mean_absolute_error: 0.4619 - mean_squared_error: 0.4191 - val_loss: 0.7639 - val_mean_absolute_error: 0.5458 - val_mean_squared_error: 0.5154
# Epoch 88/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6664 - mean_absolute_error: 0.4607 - mean_squared_error: 0.4188 - val_loss: 0.7645 - val_mean_absolute_error: 0.5457 - val_mean_squared_error: 0.5162
# Epoch 89/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6912 - mean_absolute_error: 0.4605 - mean_squared_error: 0.4187 - val_loss: 0.7646 - val_mean_absolute_error: 0.5459 - val_mean_squared_error: 0.5164
# Epoch 90/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6878 - mean_absolute_error: 0.4608 - mean_squared_error: 0.4180 - val_loss: 0.7638 - val_mean_absolute_error: 0.5456 - val_mean_squared_error: 0.5153
# Epoch 91/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6751 - mean_absolute_error: 0.4610 - mean_squared_error: 0.4173 - val_loss: 0.7633 - val_mean_absolute_error: 0.5452 - val_mean_squared_error: 0.5145
# Epoch 92/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6813 - mean_absolute_error: 0.4601 - mean_squared_error: 0.4170 - val_loss: 0.7630 - val_mean_absolute_error: 0.5444 - val_mean_squared_error: 0.5143
# Epoch 93/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6909 - mean_absolute_error: 0.4587 - mean_squared_error: 0.4167 - val_loss: 0.7632 - val_mean_absolute_error: 0.5441 - val_mean_squared_error: 0.5145
# Epoch 94/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6652 - mean_absolute_error: 0.4579 - mean_squared_error: 0.4166 - val_loss: 0.7625 - val_mean_absolute_error: 0.5437 - val_mean_squared_error: 0.5136
# Epoch 95/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6859 - mean_absolute_error: 0.4575 - mean_squared_error: 0.4161 - val_loss: 0.7622 - val_mean_absolute_error: 0.5434 - val_mean_squared_error: 0.5132
# Epoch 96/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6871 - mean_absolute_error: 0.4571 - mean_squared_error: 0.4158 - val_loss: 0.7616 - val_mean_absolute_error: 0.5429 - val_mean_squared_error: 0.5123
# Epoch 97/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6821 - mean_absolute_error: 0.4572 - mean_squared_error: 0.4155 - val_loss: 0.7607 - val_mean_absolute_error: 0.5427 - val_mean_squared_error: 0.5111
# Epoch 98/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6740 - mean_absolute_error: 0.4570 - mean_squared_error: 0.4151 - val_loss: 0.7604 - val_mean_absolute_error: 0.5424 - val_mean_squared_error: 0.5107
# Epoch 99/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6724 - mean_absolute_error: 0.4567 - mean_squared_error: 0.4147 - val_loss: 0.7586 - val_mean_absolute_error: 0.5413 - val_mean_squared_error: 0.5081
# Epoch 100/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6787 - mean_absolute_error: 0.4568 - mean_squared_error: 0.4140 - val_loss: 0.7575 - val_mean_absolute_error: 0.5407 - val_mean_squared_error: 0.5066
# [04:17:46] ======== Monitor (0): HostSketchContainer ========
# [04:17:46] AllReduce: 1e-05s, 1 calls @ 10us
#
# [04:17:46] MakeCuts: 3e-05s, 1 calls @ 30us
#
# [04:17:46] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [04:17:46] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [04:17:47] ======== Monitor (0):  ========
# [04:17:47] InitCompressedData: 3.5e-05s, 1 calls @ 35us
# /usr/local/lib/python3.10/dist-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cuda
#   warnings.warn(f"Device used : {self.device}")
# [04:17:47] ======== Monitor (0): Learner ========
# [04:17:47] Configure: 1.02392s, 1 calls @ 1023917us
#
# [04:17:47] EvalOneIter: 0.001004s, 250 calls @ 1004us
#
# [04:17:47] GetGradient: 0.010665s, 250 calls @ 10665us
#
# [04:17:47] PredictRaw: 0.000388s, 250 calls @ 388us
#
# [04:17:47] UpdateOneIter: 1.59015s, 250 calls @ 1590146us
#
# [04:17:47] ======== Monitor (0): GBTree ========
# [04:17:47] BoostNewTrees: 0.551433s, 250 calls @ 551433us
#
# [04:17:47] CommitModel: 0.000124s, 250 calls @ 124us
#
# [04:17:47] ======== Device 0 Memory Allocations:  ========
# [04:17:47] Peak memory usage: 32MiB
# [04:17:47] Number of allocations: 22242
# [04:17:47] ======== Monitor (0): updater_gpu_hist ========
# [04:17:47] InitData: 0.000854s, 750 calls @ 854us
#
# [04:17:47] InitDataOnce: 0.00071s, 1 calls @ 710us
#
# [04:17:47] Update: 0.510568s, 750 calls @ 510568us
#
# [04:17:47] UpdatePredictionCache: 0.020747s, 750 calls @ 20747us
#
# [04:17:47] ======== Monitor (0): gradient_based_sampler ========
# [04:17:47] Sample: 0.001891s, 750 calls @ 1891us
#
# [04:17:47] ======== Monitor (0): GPUHistMakerDevice0 ========
# [04:17:47] AllReduce: 0.001101s, 2148 calls @ 1101us
#
# [04:17:47] BuildHist: 0.027077s, 1677 calls @ 27077us
#
# [04:17:47] EvaluateSplits: 0.132296s, 1677 calls @ 132296us
#
# [04:17:47] FinalisePosition: 0.028537s, 750 calls @ 28537us
#
# [04:17:47] InitRoot: 0.131582s, 750 calls @ 131582us
#
# [04:17:47] Reset: 0.084176s, 750 calls @ 84176us
#
# [04:17:47] UpdatePosition: 0.09743s, 1677 calls @ 97430us
#
# epoch 0  | loss: 1.6084  | val_0_mae: 0.80925 |  0:00:00s
# epoch 1  | loss: 0.84887 | val_0_mae: 0.82408 |  0:00:00s
# epoch 2  | loss: 0.78323 | val_0_mae: 0.81148 |  0:00:01s
# epoch 3  | loss: 0.98315 | val_0_mae: 0.84734 |  0:00:01s
# epoch 4  | loss: 0.82117 | val_0_mae: 0.81327 |  0:00:01s
# epoch 5  | loss: 0.58681 | val_0_mae: 0.82199 |  0:00:02s
# epoch 6  | loss: 0.67955 | val_0_mae: 0.83904 |  0:00:03s
# epoch 7  | loss: 0.62707 | val_0_mae: 0.8228  |  0:00:03s
# epoch 8  | loss: 0.63268 | val_0_mae: 0.78749 |  0:00:03s
# epoch 9  | loss: 0.53487 | val_0_mae: 0.77711 |  0:00:03s
# epoch 10 | loss: 0.64838 | val_0_mae: 0.75513 |  0:00:04s
# epoch 11 | loss: 0.66001 | val_0_mae: 0.76634 |  0:00:04s
# epoch 12 | loss: 0.75954 | val_0_mae: 0.78122 |  0:00:05s
# epoch 13 | loss: 0.67265 | val_0_mae: 0.74194 |  0:00:05s
# epoch 14 | loss: 0.55519 | val_0_mae: 0.76883 |  0:00:05s
# epoch 15 | loss: 0.78121 | val_0_mae: 0.7933  |  0:00:05s
# epoch 16 | loss: 0.77073 | val_0_mae: 0.71077 |  0:00:06s
# epoch 17 | loss: 0.58706 | val_0_mae: 0.70395 |  0:00:06s
# epoch 18 | loss: 0.67805 | val_0_mae: 0.73289 |  0:00:07s
# epoch 19 | loss: 0.73488 | val_0_mae: 0.5767  |  0:00:07s
# epoch 20 | loss: 0.65603 | val_0_mae: 0.57882 |  0:00:07s
# epoch 21 | loss: 0.53846 | val_0_mae: 0.72457 |  0:00:08s
# epoch 22 | loss: 0.54872 | val_0_mae: 0.66981 |  0:00:08s
# epoch 23 | loss: 0.47179 | val_0_mae: 0.59651 |  0:00:09s
# epoch 24 | loss: 0.65197 | val_0_mae: 0.58619 |  0:00:09s
# epoch 25 | loss: 0.65641 | val_0_mae: 0.54737 |  0:00:09s
# epoch 26 | loss: 0.52161 | val_0_mae: 0.52494 |  0:00:09s
# epoch 27 | loss: 0.6666  | val_0_mae: 0.51118 |  0:00:10s
# epoch 28 | loss: 0.5476  | val_0_mae: 0.51086 |  0:00:10s
# epoch 29 | loss: 0.59525 | val_0_mae: 0.51253 |  0:00:10s
# epoch 30 | loss: 0.6482  | val_0_mae: 0.47607 |  0:00:11s
# epoch 31 | loss: 0.48535 | val_0_mae: 0.46798 |  0:00:11s
# epoch 32 | loss: 0.67231 | val_0_mae: 0.53591 |  0:00:12s
# epoch 33 | loss: 0.57802 | val_0_mae: 0.53382 |  0:00:12s
# epoch 34 | loss: 0.5079  | val_0_mae: 0.51224 |  0:00:12s
# epoch 35 | loss: 0.53705 | val_0_mae: 0.54803 |  0:00:13s
# epoch 36 | loss: 0.49639 | val_0_mae: 0.5768  |  0:00:13s
# epoch 37 | loss: 0.57063 | val_0_mae: 0.51565 |  0:00:14s
# epoch 38 | loss: 0.4938  | val_0_mae: 0.50758 |  0:00:14s
# epoch 39 | loss: 0.71472 | val_0_mae: 0.5636  |  0:00:14s
# epoch 40 | loss: 0.54808 | val_0_mae: 0.51797 |  0:00:15s
# epoch 41 | loss: 0.5419  | val_0_mae: 0.56149 |  0:00:15s
#
# Early stopping occurred at epoch 41 with best_epoch = 31 and best_val_0_mae = 0.46798
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 128)               768
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  dense_8 (Dense)             (None, 16)                528
#
#  dense_9 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 11683 (45.64 KB)
# Trainable params: 11683 (45.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# 3/3 [==============================] - 3s 273ms/step - loss: 1.2497 - mean_absolute_error: 0.9911 - mean_squared_error: 1.4478 - val_loss: 1.1928 - val_mean_absolute_error: 0.9710 - val_mean_squared_error: 1.3141
# Epoch 2/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.2285 - mean_absolute_error: 0.9763 - mean_squared_error: 1.3995 - val_loss: 1.1743 - val_mean_absolute_error: 0.9588 - val_mean_squared_error: 1.2723
# Epoch 3/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2107 - mean_absolute_error: 0.9628 - mean_squared_error: 1.3567 - val_loss: 1.1564 - val_mean_absolute_error: 0.9467 - val_mean_squared_error: 1.2323
# Epoch 4/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1915 - mean_absolute_error: 0.9494 - mean_squared_error: 1.3154 - val_loss: 1.1392 - val_mean_absolute_error: 0.9351 - val_mean_squared_error: 1.1944
# Epoch 5/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1719 - mean_absolute_error: 0.9363 - mean_squared_error: 1.2751 - val_loss: 1.1225 - val_mean_absolute_error: 0.9239 - val_mean_squared_error: 1.1583
# Epoch 6/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.1593 - mean_absolute_error: 0.9241 - mean_squared_error: 1.2399 - val_loss: 1.1059 - val_mean_absolute_error: 0.9123 - val_mean_squared_error: 1.1228
# Epoch 7/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.1388 - mean_absolute_error: 0.9108 - mean_squared_error: 1.2033 - val_loss: 1.0899 - val_mean_absolute_error: 0.9008 - val_mean_squared_error: 1.0894
# Epoch 8/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.1247 - mean_absolute_error: 0.8980 - mean_squared_error: 1.1696 - val_loss: 1.0750 - val_mean_absolute_error: 0.8895 - val_mean_squared_error: 1.0585
# Epoch 9/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.1095 - mean_absolute_error: 0.8851 - mean_squared_error: 1.1353 - val_loss: 1.0606 - val_mean_absolute_error: 0.8784 - val_mean_squared_error: 1.0292
# Epoch 10/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0965 - mean_absolute_error: 0.8734 - mean_squared_error: 1.1058 - val_loss: 1.0469 - val_mean_absolute_error: 0.8677 - val_mean_squared_error: 1.0016
# Epoch 11/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0828 - mean_absolute_error: 0.8619 - mean_squared_error: 1.0777 - val_loss: 1.0343 - val_mean_absolute_error: 0.8580 - val_mean_squared_error: 0.9766
# Epoch 12/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0714 - mean_absolute_error: 0.8520 - mean_squared_error: 1.0535 - val_loss: 1.0223 - val_mean_absolute_error: 0.8489 - val_mean_squared_error: 0.9531
# Epoch 13/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0606 - mean_absolute_error: 0.8423 - mean_squared_error: 1.0297 - val_loss: 1.0106 - val_mean_absolute_error: 0.8398 - val_mean_squared_error: 0.9306
# Epoch 14/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0459 - mean_absolute_error: 0.8329 - mean_squared_error: 1.0071 - val_loss: 0.9999 - val_mean_absolute_error: 0.8310 - val_mean_squared_error: 0.9099
# Epoch 15/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0340 - mean_absolute_error: 0.8240 - mean_squared_error: 0.9868 - val_loss: 0.9904 - val_mean_absolute_error: 0.8229 - val_mean_squared_error: 0.8920
# Epoch 16/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0196 - mean_absolute_error: 0.8150 - mean_squared_error: 0.9667 - val_loss: 0.9812 - val_mean_absolute_error: 0.8148 - val_mean_squared_error: 0.8749
# Epoch 17/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0185 - mean_absolute_error: 0.8067 - mean_squared_error: 0.9480 - val_loss: 0.9727 - val_mean_absolute_error: 0.8069 - val_mean_squared_error: 0.8590
# Epoch 18/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0066 - mean_absolute_error: 0.7990 - mean_squared_error: 0.9327 - val_loss: 0.9653 - val_mean_absolute_error: 0.8002 - val_mean_squared_error: 0.8454
# Epoch 19/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0025 - mean_absolute_error: 0.7922 - mean_squared_error: 0.9184 - val_loss: 0.9602 - val_mean_absolute_error: 0.7944 - val_mean_squared_error: 0.8362
# Epoch 20/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9957 - mean_absolute_error: 0.7862 - mean_squared_error: 0.9062 - val_loss: 0.9552 - val_mean_absolute_error: 0.7891 - val_mean_squared_error: 0.8271
# Epoch 21/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9873 - mean_absolute_error: 0.7810 - mean_squared_error: 0.8959 - val_loss: 0.9502 - val_mean_absolute_error: 0.7842 - val_mean_squared_error: 0.8181
# Epoch 22/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9846 - mean_absolute_error: 0.7764 - mean_squared_error: 0.8862 - val_loss: 0.9454 - val_mean_absolute_error: 0.7801 - val_mean_squared_error: 0.8096
# Epoch 23/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9816 - mean_absolute_error: 0.7720 - mean_squared_error: 0.8763 - val_loss: 0.9407 - val_mean_absolute_error: 0.7764 - val_mean_squared_error: 0.8011
# Epoch 24/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9693 - mean_absolute_error: 0.7675 - mean_squared_error: 0.8663 - val_loss: 0.9364 - val_mean_absolute_error: 0.7732 - val_mean_squared_error: 0.7936
# Epoch 25/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9711 - mean_absolute_error: 0.7636 - mean_squared_error: 0.8579 - val_loss: 0.9323 - val_mean_absolute_error: 0.7699 - val_mean_squared_error: 0.7863
# Epoch 26/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9584 - mean_absolute_error: 0.7594 - mean_squared_error: 0.8493 - val_loss: 0.9283 - val_mean_absolute_error: 0.7666 - val_mean_squared_error: 0.7792
# Epoch 27/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9619 - mean_absolute_error: 0.7557 - mean_squared_error: 0.8415 - val_loss: 0.9242 - val_mean_absolute_error: 0.7631 - val_mean_squared_error: 0.7721
# Epoch 28/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9485 - mean_absolute_error: 0.7523 - mean_squared_error: 0.8344 - val_loss: 0.9204 - val_mean_absolute_error: 0.7595 - val_mean_squared_error: 0.7655
# Epoch 29/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9522 - mean_absolute_error: 0.7487 - mean_squared_error: 0.8271 - val_loss: 0.9166 - val_mean_absolute_error: 0.7554 - val_mean_squared_error: 0.7590
# Epoch 30/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9497 - mean_absolute_error: 0.7445 - mean_squared_error: 0.8205 - val_loss: 0.9129 - val_mean_absolute_error: 0.7513 - val_mean_squared_error: 0.7527
# Epoch 31/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9467 - mean_absolute_error: 0.7410 - mean_squared_error: 0.8144 - val_loss: 0.9095 - val_mean_absolute_error: 0.7476 - val_mean_squared_error: 0.7468
# Epoch 32/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9440 - mean_absolute_error: 0.7379 - mean_squared_error: 0.8084 - val_loss: 0.9063 - val_mean_absolute_error: 0.7441 - val_mean_squared_error: 0.7414
# Epoch 33/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9407 - mean_absolute_error: 0.7349 - mean_squared_error: 0.8023 - val_loss: 0.9032 - val_mean_absolute_error: 0.7405 - val_mean_squared_error: 0.7360
# Epoch 34/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9323 - mean_absolute_error: 0.7324 - mean_squared_error: 0.7972 - val_loss: 0.9002 - val_mean_absolute_error: 0.7375 - val_mean_squared_error: 0.7310
# Epoch 35/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9306 - mean_absolute_error: 0.7299 - mean_squared_error: 0.7922 - val_loss: 0.8978 - val_mean_absolute_error: 0.7347 - val_mean_squared_error: 0.7270
# Epoch 36/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.9316 - mean_absolute_error: 0.7278 - mean_squared_error: 0.7879 - val_loss: 0.8959 - val_mean_absolute_error: 0.7321 - val_mean_squared_error: 0.7238
# Epoch 37/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9244 - mean_absolute_error: 0.7255 - mean_squared_error: 0.7841 - val_loss: 0.8942 - val_mean_absolute_error: 0.7299 - val_mean_squared_error: 0.7208
# Epoch 38/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9277 - mean_absolute_error: 0.7238 - mean_squared_error: 0.7806 - val_loss: 0.8923 - val_mean_absolute_error: 0.7277 - val_mean_squared_error: 0.7178
# Epoch 39/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9230 - mean_absolute_error: 0.7220 - mean_squared_error: 0.7772 - val_loss: 0.8905 - val_mean_absolute_error: 0.7255 - val_mean_squared_error: 0.7148
# Epoch 40/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9185 - mean_absolute_error: 0.7204 - mean_squared_error: 0.7739 - val_loss: 0.8886 - val_mean_absolute_error: 0.7231 - val_mean_squared_error: 0.7116
# Epoch 41/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9164 - mean_absolute_error: 0.7184 - mean_squared_error: 0.7701 - val_loss: 0.8863 - val_mean_absolute_error: 0.7204 - val_mean_squared_error: 0.7078
# Epoch 42/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9185 - mean_absolute_error: 0.7159 - mean_squared_error: 0.7657 - val_loss: 0.8842 - val_mean_absolute_error: 0.7178 - val_mean_squared_error: 0.7044
# Epoch 43/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9065 - mean_absolute_error: 0.7140 - mean_squared_error: 0.7620 - val_loss: 0.8819 - val_mean_absolute_error: 0.7155 - val_mean_squared_error: 0.7005
# Epoch 44/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9148 - mean_absolute_error: 0.7125 - mean_squared_error: 0.7581 - val_loss: 0.8795 - val_mean_absolute_error: 0.7132 - val_mean_squared_error: 0.6965
# Epoch 45/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9119 - mean_absolute_error: 0.7110 - mean_squared_error: 0.7548 - val_loss: 0.8769 - val_mean_absolute_error: 0.7103 - val_mean_squared_error: 0.6923
# Epoch 46/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9081 - mean_absolute_error: 0.7089 - mean_squared_error: 0.7508 - val_loss: 0.8747 - val_mean_absolute_error: 0.7080 - val_mean_squared_error: 0.6887
# Epoch 47/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9038 - mean_absolute_error: 0.7070 - mean_squared_error: 0.7466 - val_loss: 0.8724 - val_mean_absolute_error: 0.7056 - val_mean_squared_error: 0.6849
# Epoch 48/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9045 - mean_absolute_error: 0.7051 - mean_squared_error: 0.7432 - val_loss: 0.8706 - val_mean_absolute_error: 0.7034 - val_mean_squared_error: 0.6820
# Epoch 49/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9035 - mean_absolute_error: 0.7033 - mean_squared_error: 0.7399 - val_loss: 0.8684 - val_mean_absolute_error: 0.7011 - val_mean_squared_error: 0.6784
# Epoch 50/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8999 - mean_absolute_error: 0.7016 - mean_squared_error: 0.7361 - val_loss: 0.8657 - val_mean_absolute_error: 0.6989 - val_mean_squared_error: 0.6740
# Epoch 51/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8998 - mean_absolute_error: 0.7001 - mean_squared_error: 0.7319 - val_loss: 0.8625 - val_mean_absolute_error: 0.6963 - val_mean_squared_error: 0.6689
# Epoch 52/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8917 - mean_absolute_error: 0.6978 - mean_squared_error: 0.7268 - val_loss: 0.8585 - val_mean_absolute_error: 0.6928 - val_mean_squared_error: 0.6625
# Epoch 53/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8861 - mean_absolute_error: 0.6951 - mean_squared_error: 0.7208 - val_loss: 0.8547 - val_mean_absolute_error: 0.6894 - val_mean_squared_error: 0.6563
# Epoch 54/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8865 - mean_absolute_error: 0.6923 - mean_squared_error: 0.7146 - val_loss: 0.8509 - val_mean_absolute_error: 0.6858 - val_mean_squared_error: 0.6501
# Epoch 55/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8751 - mean_absolute_error: 0.6892 - mean_squared_error: 0.7083 - val_loss: 0.8465 - val_mean_absolute_error: 0.6818 - val_mean_squared_error: 0.6432
# Epoch 56/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8771 - mean_absolute_error: 0.6857 - mean_squared_error: 0.7016 - val_loss: 0.8415 - val_mean_absolute_error: 0.6779 - val_mean_squared_error: 0.6352
# Epoch 57/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8729 - mean_absolute_error: 0.6819 - mean_squared_error: 0.6938 - val_loss: 0.8358 - val_mean_absolute_error: 0.6736 - val_mean_squared_error: 0.6262
# Epoch 58/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8564 - mean_absolute_error: 0.6778 - mean_squared_error: 0.6857 - val_loss: 0.8298 - val_mean_absolute_error: 0.6687 - val_mean_squared_error: 0.6169
# Epoch 59/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8609 - mean_absolute_error: 0.6731 - mean_squared_error: 0.6767 - val_loss: 0.8241 - val_mean_absolute_error: 0.6635 - val_mean_squared_error: 0.6079
# Epoch 60/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8560 - mean_absolute_error: 0.6689 - mean_squared_error: 0.6690 - val_loss: 0.8176 - val_mean_absolute_error: 0.6576 - val_mean_squared_error: 0.5980
# Epoch 61/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8475 - mean_absolute_error: 0.6642 - mean_squared_error: 0.6604 - val_loss: 0.8111 - val_mean_absolute_error: 0.6513 - val_mean_squared_error: 0.5879
# Epoch 62/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8493 - mean_absolute_error: 0.6588 - mean_squared_error: 0.6512 - val_loss: 0.8052 - val_mean_absolute_error: 0.6455 - val_mean_squared_error: 0.5789
# Epoch 63/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8449 - mean_absolute_error: 0.6548 - mean_squared_error: 0.6430 - val_loss: 0.7990 - val_mean_absolute_error: 0.6395 - val_mean_squared_error: 0.5697
# Epoch 64/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8368 - mean_absolute_error: 0.6501 - mean_squared_error: 0.6335 - val_loss: 0.7928 - val_mean_absolute_error: 0.6332 - val_mean_squared_error: 0.5604
# Epoch 65/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8220 - mean_absolute_error: 0.6456 - mean_squared_error: 0.6251 - val_loss: 0.7865 - val_mean_absolute_error: 0.6266 - val_mean_squared_error: 0.5510
# Epoch 66/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8160 - mean_absolute_error: 0.6410 - mean_squared_error: 0.6169 - val_loss: 0.7811 - val_mean_absolute_error: 0.6209 - val_mean_squared_error: 0.5431
# Epoch 67/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8232 - mean_absolute_error: 0.6363 - mean_squared_error: 0.6093 - val_loss: 0.7762 - val_mean_absolute_error: 0.6155 - val_mean_squared_error: 0.5358
# Epoch 68/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8199 - mean_absolute_error: 0.6318 - mean_squared_error: 0.6024 - val_loss: 0.7714 - val_mean_absolute_error: 0.6103 - val_mean_squared_error: 0.5289
# Epoch 69/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8158 - mean_absolute_error: 0.6278 - mean_squared_error: 0.5957 - val_loss: 0.7669 - val_mean_absolute_error: 0.6057 - val_mean_squared_error: 0.5225
# Epoch 70/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8109 - mean_absolute_error: 0.6242 - mean_squared_error: 0.5897 - val_loss: 0.7624 - val_mean_absolute_error: 0.6011 - val_mean_squared_error: 0.5160
# Epoch 71/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8032 - mean_absolute_error: 0.6204 - mean_squared_error: 0.5839 - val_loss: 0.7581 - val_mean_absolute_error: 0.5964 - val_mean_squared_error: 0.5098
# Epoch 72/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7981 - mean_absolute_error: 0.6165 - mean_squared_error: 0.5782 - val_loss: 0.7540 - val_mean_absolute_error: 0.5918 - val_mean_squared_error: 0.5041
# Epoch 73/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8003 - mean_absolute_error: 0.6126 - mean_squared_error: 0.5730 - val_loss: 0.7504 - val_mean_absolute_error: 0.5877 - val_mean_squared_error: 0.4990
# Epoch 74/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7975 - mean_absolute_error: 0.6090 - mean_squared_error: 0.5678 - val_loss: 0.7469 - val_mean_absolute_error: 0.5840 - val_mean_squared_error: 0.4941
# Epoch 75/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7895 - mean_absolute_error: 0.6058 - mean_squared_error: 0.5631 - val_loss: 0.7436 - val_mean_absolute_error: 0.5803 - val_mean_squared_error: 0.4895
# Epoch 76/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7868 - mean_absolute_error: 0.6025 - mean_squared_error: 0.5585 - val_loss: 0.7404 - val_mean_absolute_error: 0.5766 - val_mean_squared_error: 0.4851
# Epoch 77/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7858 - mean_absolute_error: 0.5997 - mean_squared_error: 0.5545 - val_loss: 0.7372 - val_mean_absolute_error: 0.5729 - val_mean_squared_error: 0.4807
# Epoch 78/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7838 - mean_absolute_error: 0.5967 - mean_squared_error: 0.5502 - val_loss: 0.7341 - val_mean_absolute_error: 0.5692 - val_mean_squared_error: 0.4765
# Epoch 79/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7810 - mean_absolute_error: 0.5938 - mean_squared_error: 0.5462 - val_loss: 0.7311 - val_mean_absolute_error: 0.5651 - val_mean_squared_error: 0.4723
# Epoch 80/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7790 - mean_absolute_error: 0.5909 - mean_squared_error: 0.5425 - val_loss: 0.7282 - val_mean_absolute_error: 0.5612 - val_mean_squared_error: 0.4685
# Epoch 81/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7728 - mean_absolute_error: 0.5879 - mean_squared_error: 0.5387 - val_loss: 0.7255 - val_mean_absolute_error: 0.5572 - val_mean_squared_error: 0.4648
# Epoch 82/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7711 - mean_absolute_error: 0.5848 - mean_squared_error: 0.5353 - val_loss: 0.7227 - val_mean_absolute_error: 0.5529 - val_mean_squared_error: 0.4611
# Epoch 83/100
# ...
# 3/3 [==============================] - 0s 20ms/step - loss: 0.7445 - mean_absolute_error: 0.5822 - mean_squared_error: 0.4949 - val_loss: 0.9436 - val_mean_absolute_error: 0.7082 - val_mean_squared_error: 0.8033
# Epoch 48/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7462 - mean_absolute_error: 0.5791 - mean_squared_error: 0.4911 - val_loss: 0.9426 - val_mean_absolute_error: 0.7067 - val_mean_squared_error: 0.8015
# Epoch 49/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7412 - mean_absolute_error: 0.5758 - mean_squared_error: 0.4873 - val_loss: 0.9416 - val_mean_absolute_error: 0.7050 - val_mean_squared_error: 0.7998
# Epoch 50/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7397 - mean_absolute_error: 0.5723 - mean_squared_error: 0.4833 - val_loss: 0.9406 - val_mean_absolute_error: 0.7035 - val_mean_squared_error: 0.7981
# Epoch 51/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.7358 - mean_absolute_error: 0.5692 - mean_squared_error: 0.4796 - val_loss: 0.9397 - val_mean_absolute_error: 0.7020 - val_mean_squared_error: 0.7965
# Epoch 52/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7334 - mean_absolute_error: 0.5658 - mean_squared_error: 0.4759 - val_loss: 0.9389 - val_mean_absolute_error: 0.7011 - val_mean_squared_error: 0.7951
# Epoch 53/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7276 - mean_absolute_error: 0.5642 - mean_squared_error: 0.4727 - val_loss: 0.9381 - val_mean_absolute_error: 0.7017 - val_mean_squared_error: 0.7938
# Epoch 54/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7314 - mean_absolute_error: 0.5621 - mean_squared_error: 0.4686 - val_loss: 0.9372 - val_mean_absolute_error: 0.7009 - val_mean_squared_error: 0.7922
# Epoch 55/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7286 - mean_absolute_error: 0.5597 - mean_squared_error: 0.4650 - val_loss: 0.9363 - val_mean_absolute_error: 0.6999 - val_mean_squared_error: 0.7906
# Epoch 56/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7131 - mean_absolute_error: 0.5570 - mean_squared_error: 0.4620 - val_loss: 0.9353 - val_mean_absolute_error: 0.6983 - val_mean_squared_error: 0.7890
# Epoch 57/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7221 - mean_absolute_error: 0.5539 - mean_squared_error: 0.4580 - val_loss: 0.9344 - val_mean_absolute_error: 0.6972 - val_mean_squared_error: 0.7875
# Epoch 58/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7170 - mean_absolute_error: 0.5510 - mean_squared_error: 0.4545 - val_loss: 0.9335 - val_mean_absolute_error: 0.6954 - val_mean_squared_error: 0.7859
# Epoch 59/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7061 - mean_absolute_error: 0.5476 - mean_squared_error: 0.4509 - val_loss: 0.9326 - val_mean_absolute_error: 0.6929 - val_mean_squared_error: 0.7843
# Epoch 60/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7128 - mean_absolute_error: 0.5438 - mean_squared_error: 0.4469 - val_loss: 0.9316 - val_mean_absolute_error: 0.6907 - val_mean_squared_error: 0.7826
# Epoch 61/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7073 - mean_absolute_error: 0.5403 - mean_squared_error: 0.4432 - val_loss: 0.9307 - val_mean_absolute_error: 0.6878 - val_mean_squared_error: 0.7811
# Epoch 62/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7049 - mean_absolute_error: 0.5365 - mean_squared_error: 0.4397 - val_loss: 0.9300 - val_mean_absolute_error: 0.6855 - val_mean_squared_error: 0.7798
# Epoch 63/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7049 - mean_absolute_error: 0.5333 - mean_squared_error: 0.4363 - val_loss: 0.9292 - val_mean_absolute_error: 0.6842 - val_mean_squared_error: 0.7785
# Epoch 64/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6985 - mean_absolute_error: 0.5304 - mean_squared_error: 0.4325 - val_loss: 0.9284 - val_mean_absolute_error: 0.6829 - val_mean_squared_error: 0.7771
# Epoch 65/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7014 - mean_absolute_error: 0.5274 - mean_squared_error: 0.4289 - val_loss: 0.9276 - val_mean_absolute_error: 0.6810 - val_mean_squared_error: 0.7757
# Epoch 66/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6941 - mean_absolute_error: 0.5247 - mean_squared_error: 0.4253 - val_loss: 0.9267 - val_mean_absolute_error: 0.6804 - val_mean_squared_error: 0.7743
# Epoch 67/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6899 - mean_absolute_error: 0.5231 - mean_squared_error: 0.4219 - val_loss: 0.9260 - val_mean_absolute_error: 0.6787 - val_mean_squared_error: 0.7730
# Epoch 68/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6920 - mean_absolute_error: 0.5196 - mean_squared_error: 0.4184 - val_loss: 0.9253 - val_mean_absolute_error: 0.6756 - val_mean_squared_error: 0.7719
# Epoch 69/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6888 - mean_absolute_error: 0.5149 - mean_squared_error: 0.4148 - val_loss: 0.9247 - val_mean_absolute_error: 0.6733 - val_mean_squared_error: 0.7709
# Epoch 70/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6757 - mean_absolute_error: 0.5119 - mean_squared_error: 0.4116 - val_loss: 0.9240 - val_mean_absolute_error: 0.6726 - val_mean_squared_error: 0.7698
# Epoch 71/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6844 - mean_absolute_error: 0.5097 - mean_squared_error: 0.4083 - val_loss: 0.9235 - val_mean_absolute_error: 0.6719 - val_mean_squared_error: 0.7688
# Epoch 72/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6800 - mean_absolute_error: 0.5066 - mean_squared_error: 0.4047 - val_loss: 0.9229 - val_mean_absolute_error: 0.6710 - val_mean_squared_error: 0.7679
# Epoch 73/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6739 - mean_absolute_error: 0.5039 - mean_squared_error: 0.4020 - val_loss: 0.9224 - val_mean_absolute_error: 0.6701 - val_mean_squared_error: 0.7669
# Epoch 74/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6770 - mean_absolute_error: 0.5005 - mean_squared_error: 0.3985 - val_loss: 0.9218 - val_mean_absolute_error: 0.6703 - val_mean_squared_error: 0.7660
# Epoch 75/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6732 - mean_absolute_error: 0.4998 - mean_squared_error: 0.3959 - val_loss: 0.9212 - val_mean_absolute_error: 0.6718 - val_mean_squared_error: 0.7650
# Epoch 76/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6622 - mean_absolute_error: 0.4994 - mean_squared_error: 0.3934 - val_loss: 0.9207 - val_mean_absolute_error: 0.6716 - val_mean_squared_error: 0.7642
# Epoch 77/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6711 - mean_absolute_error: 0.4978 - mean_squared_error: 0.3907 - val_loss: 0.9204 - val_mean_absolute_error: 0.6707 - val_mean_squared_error: 0.7636
# Epoch 78/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6610 - mean_absolute_error: 0.4950 - mean_squared_error: 0.3880 - val_loss: 0.9202 - val_mean_absolute_error: 0.6694 - val_mean_squared_error: 0.7634
# Epoch 79/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6632 - mean_absolute_error: 0.4917 - mean_squared_error: 0.3853 - val_loss: 0.9203 - val_mean_absolute_error: 0.6681 - val_mean_squared_error: 0.7635
# Epoch 80/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6624 - mean_absolute_error: 0.4885 - mean_squared_error: 0.3831 - val_loss: 0.9201 - val_mean_absolute_error: 0.6665 - val_mean_squared_error: 0.7633
# Epoch 81/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6569 - mean_absolute_error: 0.4856 - mean_squared_error: 0.3813 - val_loss: 0.9199 - val_mean_absolute_error: 0.6650 - val_mean_squared_error: 0.7631
# Epoch 82/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6543 - mean_absolute_error: 0.4826 - mean_squared_error: 0.3787 - val_loss: 0.9196 - val_mean_absolute_error: 0.6636 - val_mean_squared_error: 0.7626
# Epoch 83/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6600 - mean_absolute_error: 0.4797 - mean_squared_error: 0.3768 - val_loss: 0.9196 - val_mean_absolute_error: 0.6618 - val_mean_squared_error: 0.7625
# Epoch 84/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6499 - mean_absolute_error: 0.4764 - mean_squared_error: 0.3748 - val_loss: 0.9195 - val_mean_absolute_error: 0.6607 - val_mean_squared_error: 0.7624
# Epoch 85/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6497 - mean_absolute_error: 0.4741 - mean_squared_error: 0.3732 - val_loss: 0.9194 - val_mean_absolute_error: 0.6599 - val_mean_squared_error: 0.7622
# Epoch 86/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6497 - mean_absolute_error: 0.4721 - mean_squared_error: 0.3714 - val_loss: 0.9191 - val_mean_absolute_error: 0.6601 - val_mean_squared_error: 0.7618
# Epoch 87/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6478 - mean_absolute_error: 0.4706 - mean_squared_error: 0.3693 - val_loss: 0.9188 - val_mean_absolute_error: 0.6607 - val_mean_squared_error: 0.7613
# Epoch 88/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6499 - mean_absolute_error: 0.4694 - mean_squared_error: 0.3671 - val_loss: 0.9186 - val_mean_absolute_error: 0.6610 - val_mean_squared_error: 0.7611
# Epoch 89/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6425 - mean_absolute_error: 0.4686 - mean_squared_error: 0.3657 - val_loss: 0.9186 - val_mean_absolute_error: 0.6613 - val_mean_squared_error: 0.7610
# Epoch 90/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6449 - mean_absolute_error: 0.4676 - mean_squared_error: 0.3640 - val_loss: 0.9184 - val_mean_absolute_error: 0.6613 - val_mean_squared_error: 0.7607
# Epoch 91/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6465 - mean_absolute_error: 0.4664 - mean_squared_error: 0.3625 - val_loss: 0.9182 - val_mean_absolute_error: 0.6605 - val_mean_squared_error: 0.7605
# Epoch 92/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6424 - mean_absolute_error: 0.4645 - mean_squared_error: 0.3612 - val_loss: 0.9181 - val_mean_absolute_error: 0.6596 - val_mean_squared_error: 0.7604
# Epoch 93/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6398 - mean_absolute_error: 0.4631 - mean_squared_error: 0.3600 - val_loss: 0.9181 - val_mean_absolute_error: 0.6587 - val_mean_squared_error: 0.7605
# Epoch 94/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6425 - mean_absolute_error: 0.4607 - mean_squared_error: 0.3585 - val_loss: 0.9184 - val_mean_absolute_error: 0.6570 - val_mean_squared_error: 0.7610
# Epoch 95/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6381 - mean_absolute_error: 0.4587 - mean_squared_error: 0.3570 - val_loss: 0.9184 - val_mean_absolute_error: 0.6580 - val_mean_squared_error: 0.7611
# Epoch 96/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6359 - mean_absolute_error: 0.4584 - mean_squared_error: 0.3552 - val_loss: 0.9187 - val_mean_absolute_error: 0.6584 - val_mean_squared_error: 0.7616
# Epoch 97/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6398 - mean_absolute_error: 0.4565 - mean_squared_error: 0.3540 - val_loss: 0.9192 - val_mean_absolute_error: 0.6582 - val_mean_squared_error: 0.7624
# Epoch 98/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6293 - mean_absolute_error: 0.4550 - mean_squared_error: 0.3530 - val_loss: 0.9194 - val_mean_absolute_error: 0.6595 - val_mean_squared_error: 0.7629
# Epoch 99/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6333 - mean_absolute_error: 0.4553 - mean_squared_error: 0.3519 - val_loss: 0.9193 - val_mean_absolute_error: 0.6613 - val_mean_squared_error: 0.7628
# Epoch 100/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6339 - mean_absolute_error: 0.4567 - mean_squared_error: 0.3508 - val_loss: 0.9194 - val_mean_absolute_error: 0.6643 - val_mean_squared_error: 0.7629
# [04:19:34] ======== Monitor (0): HostSketchContainer ========
# [04:19:34] AllReduce: 8e-06s, 1 calls @ 8us
#
# [04:19:34] MakeCuts: 1.6e-05s, 1 calls @ 16us
#
# [04:19:34] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [04:19:34] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# [04:19:34] ======== Monitor (0):  ========
# [04:19:34] InitCompressedData: 2.7e-05s, 1 calls @ 27us
#
# [04:19:34] ======== Monitor (0): Learner ========
# [04:19:34] Configure: 0.000924s, 1 calls @ 924us
#
# [04:19:34] EvalOneIter: 0.000996s, 250 calls @ 996us
#
# [04:19:34] GetGradient: 0.011188s, 250 calls @ 11188us
#
# [04:19:34] PredictRaw: 0.000238s, 250 calls @ 238us
#
# [04:19:34] UpdateOneIter: 0.551967s, 250 calls @ 551967us
#
# [04:19:34] ======== Monitor (0): GBTree ========
# [04:19:34] BoostNewTrees: 0.536617s, 250 calls @ 536617us
#
# [04:19:34] CommitModel: 0.000116s, 250 calls @ 116us
#
# [04:19:34] ======== Device 0 Memory Allocations:  ========
# [04:19:34] Peak memory usage: 32MiB
# [04:19:34] Number of allocations: 104832
# [04:19:34] ======== Monitor (0): updater_gpu_hist ========
# [04:19:34] InitData: 0.000567s, 750 calls @ 567us
#
# [04:19:34] InitDataOnce: 0.000434s, 1 calls @ 434us
#
# [04:19:34] Update: 0.495246s, 750 calls @ 495246us
#
# [04:19:34] UpdatePredictionCache: 0.020445s, 750 calls @ 20445us
#
# [04:19:34] ======== Monitor (0): gradient_based_sampler ========
# [04:19:34] Sample: 0.001506s, 750 calls @ 1506us
#
# [04:19:34] ======== Monitor (0): GPUHistMakerDevice0 ========
# [04:19:34] AllReduce: 0.001195s, 1942 calls @ 1195us
#
# [04:19:34] BuildHist: 0.024204s, 1430 calls @ 24204us
#
# [04:19:34] EvaluateSplits: 0.121873s, 1430 calls @ 121873us
#
# [04:19:34] FinalisePosition: 0.028683s, 750 calls @ 28683us
#
# [04:19:34] InitRoot: 0.138726s, 750 calls @ 138726us
#
# [04:19:34] Reset: 0.085558s, 750 calls @ 85558us
#
# [04:19:34] UpdatePosition: 0.087449s, 1430 calls @ 87449us
# /usr/local/lib/python3.10/dist-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cuda
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 1.72645 | val_0_mae: 0.79516 |  0:00:00s
# epoch 1  | loss: 0.72059 | val_0_mae: 0.82508 |  0:00:00s
# epoch 2  | loss: 0.83562 | val_0_mae: 1.00482 |  0:00:01s
# epoch 3  | loss: 0.55462 | val_0_mae: 0.72465 |  0:00:01s
# epoch 4  | loss: 0.6865  | val_0_mae: 0.68314 |  0:00:01s
# epoch 5  | loss: 0.69882 | val_0_mae: 0.7052  |  0:00:02s
# epoch 6  | loss: 0.5367  | val_0_mae: 0.72653 |  0:00:02s
# epoch 7  | loss: 0.65379 | val_0_mae: 0.71056 |  0:00:02s
# epoch 8  | loss: 0.61283 | val_0_mae: 0.67245 |  0:00:03s
# epoch 9  | loss: 0.48039 | val_0_mae: 0.67837 |  0:00:03s
# epoch 10 | loss: 0.62381 | val_0_mae: 0.6821  |  0:00:03s
# epoch 11 | loss: 0.5902  | val_0_mae: 0.68869 |  0:00:04s
# epoch 12 | loss: 0.64274 | val_0_mae: 0.70711 |  0:00:04s
# epoch 13 | loss: 0.4952  | val_0_mae: 0.69649 |  0:00:04s
# epoch 14 | loss: 0.58916 | val_0_mae: 0.683   |  0:00:05s
# epoch 15 | loss: 0.64275 | val_0_mae: 0.68424 |  0:00:05s
# epoch 16 | loss: 0.45471 | val_0_mae: 0.65235 |  0:00:05s
# epoch 17 | loss: 0.45025 | val_0_mae: 0.6678  |  0:00:06s
# epoch 18 | loss: 0.59557 | val_0_mae: 0.69717 |  0:00:06s
# epoch 19 | loss: 0.50731 | val_0_mae: 0.70478 |  0:00:06s
# epoch 20 | loss: 0.43771 | val_0_mae: 0.70454 |  0:00:07s
# epoch 21 | loss: 0.37087 | val_0_mae: 0.66922 |  0:00:07s
# epoch 22 | loss: 0.65437 | val_0_mae: 0.69895 |  0:00:08s
# epoch 23 | loss: 0.48926 | val_0_mae: 0.69679 |  0:00:08s
# epoch 24 | loss: 0.56516 | val_0_mae: 0.69799 |  0:00:08s
# epoch 25 | loss: 0.51134 | val_0_mae: 0.68709 |  0:00:09s
# epoch 26 | loss: 0.54898 | val_0_mae: 0.67168 |  0:00:09s
#
# Early stopping occurred at epoch 26 with best_epoch = 16 and best_val_0_mae = 0.65235
# /usr/local/lib/python3.10/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)

# %% [markdown]
# # EVALUATION

# %%
# Evaluation tables
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
names = ["Width","Length","Input Impedance"]
model_names = ["FNN","XGBoost","TabNet"]
num_models = len(model_dictionary)
num_targets = 3
y_pred_models = [[] for _ in range(num_models)]
y_test_targets = [[] for _ in range(num_targets)]
for i in range(num_models):
    nn_model, xgb_model, tabnet_model = model_dictionary[i]
    y_pred_nn = bc.inverse_transform(nn_model.predict(X_test))
    y_pred_xgb = bc.inverse_transform(xgb_model.predict(X_test))
    y_pred_tab = bc.inverse_transform(tabnet_model.predict(X_test))
    y_pred_models[i] = [y_pred_nn, y_pred_xgb, y_pred_tab]
    inverse_y = bc.inverse_transform(y_test)
    y_test_targets[0] = inverse_y[:, 0]
    y_test_targets[1] = inverse_y[:, 1]
    y_test_targets[2] = inverse_y[:, 2]

for t in range(num_targets):
    metrics_data = []
    y_test_target = y_test_targets[t]
    target_data = {
        "Target": names[t]
    }
    for model_type in range(len(y_pred_models[0])):
        mean = np.zeros_like(y_pred_models[0][model_type][:, t])
        squared_diff_sum = np.zeros_like(y_pred_models[0][model_type][:, t])
        for k_fold in range(len(y_pred_models)):
            y_pred_fold = y_pred_models[k_fold][model_type][:, t]
            mean += y_pred_fold
            squared_diff_sum += (y_pred_fold - mean) ** 2
        mean = mean / len(y_pred_models)
        std_deviation = np.sqrt(squared_diff_sum / len(y_pred_models))
        mse = mean_squared_error(y_test_target, mean)
        mae = mean_absolute_error(y_test_target, mean)
        rmse = np.sqrt(mse)
        r_squared = r2_score(y_test_target, mean)
        target_data[f"Mean ({model_names[model_type]})"] = mean
        target_data[f"SD ({model_names[model_type]})"] = std_deviation
        target_data[f"MSE ({model_names[model_type]})"] = mse
        target_data[f"MAE ({model_names[model_type]})"] = mae
        target_data[f"RMSE ({model_names[model_type]})"] = rmse
        target_data[f"R² ({model_names[model_type]})"] = r_squared

    metrics_data.append(target_data)
    metrics_df = pd.DataFrame(metrics_data)
    display(metrics_df)
# Out:
# 1/1 [==============================] - 0s 83ms/step
# [04:19:54] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [04:19:54] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# 1/1 [==============================] - 4s 4s/step
# [04:20:04] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [04:20:04] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# 1/1 [==============================] - 10s 10s/step
# [04:20:25] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [04:20:25] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# 1/1 [==============================] - 10s 10s/step
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7932b81cf520> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [04:20:45] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [04:20:45] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# 1/1 [==============================] - 20s 20s/step
# [04:21:06] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [04:21:06] DEBUG: /workspace/src/tree/updater_gpu_hist.cu:744: [GPU Hist]: Configure
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
#   Target                                         Mean (FNN)  \
# 0  Width  [-26.49589, -15.522408, -21.174337, -21.136349...
#
#                                             SD (FNN)  MSE (FNN)  MAE (FNN)  \
# 0  [64.92175, 36.58352, 51.46837, 51.371857, 61.9...   2.599264   1.510528
#
#    RMSE (FNN)  R² (FNN)                                     Mean (XGBoost)  \
# 0    1.612223  0.824256  [-29.182755, -17.34699, -20.083733, -20.03529,...
#
#                                         SD (XGBoost)  MSE (XGBoost)  \
# 0  [71.49005, 42.52244, 49.19087, 49.065273, 57.6...       0.110543
#
#    MAE (XGBoost)  RMSE (XGBoost)  R² (XGBoost)  \
# 0       0.217844        0.332481      0.992526
#
#                                        Mean (TabNet)  \
# 0  [-26.112635, -17.71979, -21.660616, -21.609987...
#
#                                          SD (TabNet)  MSE (TabNet)  \
# 0  [63.76471, 43.614388, 52.85961, 52.71936, 61.2...      3.617778
#
#    MAE (TabNet)  RMSE (TabNet)  R² (TabNet)
# 0      1.752305       1.902046     0.755391
#    Target                                         Mean (FNN)  \
# 0  Length  [17.10374, 50.747543, 34.948376, 35.068703, 21...
#
#                                             SD (FNN)  MSE (FNN)  MAE (FNN)  \
# 0  [42.974766, 123.63486, 85.35108, 85.63103, 56....  30.864505    5.17547
#
#    RMSE (FNN)  R² (FNN)                                     Mean (XGBoost)  \
# 0    5.555583   0.81638  [6.5285354, 46.35509, 38.836708, 38.982323, 25...
#
#                                         SD (XGBoost)  MSE (XGBoost)  \
# 0  [15.967873, 113.46954, 95.14234, 95.521255, 67...       1.455065
#
#    MAE (XGBoost)  RMSE (XGBoost)  R² (XGBoost)  \
# 0       0.769523        1.206261      0.991343
#
#                                        Mean (TabNet)  \
# 0  [18.41203, 47.398903, 33.822662, 33.999825, 22...
#
#                                          SD (TabNet)  MSE (TabNet)  \
# 0  [46.08729, 115.34113, 83.33692, 83.8048, 55.28...     42.287267
#
#    MAE (TabNet)  RMSE (TabNet)  R² (TabNet)
# 0      5.969874       6.502866     0.748423
#             Target                                         Mean (FNN)  \
# 0  Input Impedance  [37.091698, 64.06679, 50.746727, 50.870068, 37...
#
#                                             SD (FNN)   MSE (FNN)  MAE (FNN)  \
# 0  [90.97984, 158.11179, 124.6515, 124.957405, 93...  382.032949  13.980834
#
#    RMSE (FNN)  R² (FNN)                                     Mean (XGBoost)  \
# 0   19.545663  0.268273  [83.88673, 66.258644, 59.25464, 59.385193, 24....
#
#                                         SD (XGBoost)  MSE (XGBoost)  \
# 0  [205.25264, 162.09581, 145.14421, 145.36258, 5...       1.905511
#
#    MAE (XGBoost)  RMSE (XGBoost)  R² (XGBoost)  \
# 0       0.985845        1.380402       0.99635
#
#                                        Mean (TabNet)  \
# 0  [38.127155, 63.23236, 50.122753, 50.31383, 38....
#
#                                          SD (TabNet)  MSE (TabNet)  \
# 0  [95.58347, 154.56921, 124.50032, 124.989334, 9...    386.552263
#
#    MAE (TabNet)  RMSE (TabNet)  R² (TabNet)
# 0     14.564902      19.660932     0.259617

# %%
# Evaluation plots
names = ["Width","Length","Behavior"]
model_names = ["FNN","XGBoost","TabNet"]
num_models = len(model_dictionary)
num_targets = 3
y_pred_models = [[] for _ in range(num_models)]
y_test_targets = [[] for _ in range(num_targets)]
for i in range(num_models):
    nn_model, xgb_model, tabnet_model = model_dictionary[i]
    y_pred_nn = bc.inverse_transform(nn_model.predict(X_test))
    y_pred_xgb = bc.inverse_transform(xgb_model.predict(X_test))
    y_pred_tab = bc.inverse_transform(tabnet_model.predict(X_test))
    y_pred_models[i] = [y_pred_nn, y_pred_xgb, y_pred_tab]
    inverse_y = bc.inverse_transform(y_test)
    y_test_targets[0] = inverse_y[:, 0]
    y_test_targets[1] = inverse_y[:, 1]
    y_test_targets[2] = inverse_y[:, 2]
for t in range(num_targets):
  y_test_target = y_test_targets[t]
  plt.figure(figsize=(6, 4))
  plt.plot(range(len(y_test_target)), y_test_target, label='Actual', color='blue', alpha=0.7)
  for model_type in range(len(y_pred_models[0])):
    mean = np.zeros_like(y_pred_models[0][model_type][:, t])
    squared_diff_sum = np.zeros_like(y_pred_models[0][model_type][:, t])
    for k_fold in range(len(y_pred_models)):
      y_pred_fold = y_pred_models[k_fold][model_type][:, t]
      mean += y_pred_fold
    mean = mean / len(y_pred_models)
    for k_fold in range(len(y_pred_models)):
      y_pred_fold = y_pred_models[k_fold][model_type][:, t]
      squared_diff_sum += (y_pred_fold - mean) ** 2
    std_deviation = np.sqrt(squared_diff_sum / len(y_pred_models))
    std_deviation = np.sqrt(squared_diff_sum / len(y_pred_models))
    plt.plot(range(len(y_test_target)), mean, label=f'Predicted Mean (Model {model_names[model_type]})', alpha=0.7)
    plt.fill_between(range(len(y_test_target)), mean - std_deviation, mean + std_deviation, alpha=0.2, label=f'Standard Deviation (Model {model_names[model_type]})')
  plt.title(f'Simulated Actual and Predicted (Target {names[t]})')
  plt.xlabel('Data Point')
  plt.ylabel('Value')
  plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
  plt.show()
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 10s 10s/step
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 10s 10s/step
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# 1/1 [==============================] - 0s 21ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PowerTransformer was fitted with feature names
#   warnings.warn(
